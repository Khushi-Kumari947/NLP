# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushi-Kumari947/NLP/blob/main/Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#To start with we can use split() method of python
#But most of the times it fails
#then we may use regular expressions but we need to find different patterns and will increase complexity

# %%
#Most of times we use libraries

# %% [markdown]
# NLTK

# %%
# !pip install nltk

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')   # important (new NLTK versions)
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
s1='I am going to New Delhi!'
word_tokenize(s1)
# Out:
# ['I', 'am', 'going', 'to', 'New', 'Delhi', '!']

# %%
s2 = "Dr. Smith completed his Ph.D in 2022 and earned $50 per hr while walking 5 km daily, etc. BTW he lives in the U.S.A."
word_tokenize(s)
# Out:
# ['You',
#  'can',
#  'contact',
#  'me',
#  'at',
#  'johnsmith123',
#  '@',
#  'gmail.com',
#  'for',
#  'more',
#  'details',
#  '.']

# %%
s3= "You can contact me at johnsmith123@gmail.com for more details."
word_tokenize(s)
# Out:
# ['You',
#  'can',
#  'contact',
#  'me',
#  'at',
#  'johnsmith123',
#  '@',
#  'gmail.com',
#  'for',
#  'more',
#  'details',
#  '.']

# %%
#So NLTK also sometimes fails therefore right now best library is spacy

# %% [markdown]
# Spacy

# %%
import spacy

# %%
nlp=spacy.load('en_core_web_sm')

# %%
doc1=nlp(s1)
doc2=nlp(s2)
doc3=nlp(s3)

# %%
for token in doc2:
  print(token)
# Out:
# Dr.
# Smith
# completed
# his
# Ph
# .
# D
# in
# 2022
# and
# earned
# $
# 50
# per
# hr
# while
# walking
# 5
# km
# daily
# ,
# etc
# .
# BTW
# he
# lives
# in
# the
# U.S.A.

# %%
#Not always a single method is good
